# %%
pip install snowflake-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from snowflake.connector.pandas_tools import write_pandas
import snowflake.connector
import pandas as pd

# Step 1: Read cleaned CSV
df = pd.read_csv('cleaned_export.csv')

# Step 2: Ensure all column names match Snowflake table (convert to uppercase)
df.columns = [col.upper() for col in df.columns]

# Step 3: Connect to Snowflake
ctx = snowflake.connector.connect(
    user='Anuj7678',
    password='AnujDaphale2004',
    account='PPWUBWY-RO47801',   # Make sure this matches your Account Identifier
    warehouse='COMPUTE_WH',
    database='VALORANT_DB',
    schema='PUBLIC'
)

# Step 4: Upload to Snowflake
write_pandas(
    ctx,
    df,
    'VALORANT_PLAYERS',   # Use the same name as the table in Snowflake
    database='VALORANT_DB',
    schema='PUBLIC'
)

print("✅ Data uploaded successfully!")
ctx.close()
# Out:
# ✅ Data uploaded successfully!
